# %%
#Import necessary modules

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import random

from citipy import citipy

import time

from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_key

# %%
# Build base url + key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %%
# Create a set of random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats,lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Conditions" : city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | pacific grove
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | johnstown
# Processing Record 14 of Set 1 | sangin
# Processing Record 15 of Set 1 | sao miguel do araguaia
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | san patricio
# Processing Record 23 of Set 1 | dingle
# Processing Record 24 of Set 1 | kavieng
# Processing Record 25 of Set 1 | andenes
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | hvolsvollur
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | mbanza-ngungu
# Processing Record 30 of Set 1 | vega de alatorre
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | zhezkazgan
# Processing Record 38 of Set 1 | uige
# Processing Record 39 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 1 | pangkalanbuun
# Processing Record 41 of Set 1 | buala
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | contamana
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | solnechnyy
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | san andres
# Processing Record 50 of Set 1 | luderitz
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | hasaki
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | chapais
# Processing Record 8 of Set 2 | alice springs
# Processing Record 9 of Set 2 | narok
# Processing Record 10 of Set 2 | askarovo
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 2 | manuk mangkaw
# Processing Record 15 of Set 2 | faya
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | samarai
# Processing Record 18 of Set 2 | port moresby
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 2 | hit
# Processing Record 22 of Set 2 | karakose
# City not found. Skipping...
# Processing Record 23 of Set 2 | port hardy
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | cabedelo
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | caravelas
# Processing Record 28 of Set 2 | anzhero-sudzhensk
# Processing Record 29 of Set 2 | ayan
# Processing Record 30 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | challapata
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | sumenep
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | changping
# Processing Record 37 of Set 2 | te anau
# Processing Record 38 of Set 2 | bulaevo
# Processing Record 39 of Set 2 | victoria
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | virginia beach
# Processing Record 42 of Set 2 | codrington
# Processing Record 43 of Set 2 | saint anthony
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | malinovoye ozero
# Processing Record 46 of Set 2 | finschhafen
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | ylojarvi
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | sabaudia
# Processing Record 1 of Set 3 | naze
# Processing Record 2 of Set 3 | cockburn town
# Processing Record 3 of Set 3 | dunedin
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | norman wells
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | nishihara
# Processing Record 8 of Set 3 | huilong
# Processing Record 9 of Set 3 | japura
# Processing Record 10 of Set 3 | khartoum
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | kawalu
# Processing Record 13 of Set 3 | puerto ayora
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | mapiripan
# Processing Record 17 of Set 3 | ranong
# Processing Record 18 of Set 3 | sula
# Processing Record 19 of Set 3 | ahipara
# Processing Record 20 of Set 3 | noumea
# Processing Record 21 of Set 3 | touros
# Processing Record 22 of Set 3 | marsaxlokk
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | mucurapo
# Processing Record 25 of Set 3 | saint-pierre
# Processing Record 26 of Set 3 | flin flon
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | waddan
# Processing Record 29 of Set 3 | tucurui
# Processing Record 30 of Set 3 | tuktoyaktuk
# Processing Record 31 of Set 3 | belmonte
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | polunochnoye
# Processing Record 34 of Set 3 | cotia
# Processing Record 35 of Set 3 | cabra
# Processing Record 36 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 3 | qaqortoq
# Processing Record 38 of Set 3 | akyab
# Processing Record 39 of Set 3 | atascadero
# Processing Record 40 of Set 3 | belur
# Processing Record 41 of Set 3 | port pirie
# Processing Record 42 of Set 3 | gamba
# Processing Record 43 of Set 3 | zhuhai
# Processing Record 44 of Set 3 | cayenne
# Processing Record 45 of Set 3 | araguaina
# Processing Record 46 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 3 | dakar
# Processing Record 50 of Set 3 | broken hill
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | pochutla
# Processing Record 3 of Set 4 | stepnoye
# Processing Record 4 of Set 4 | lodja
# Processing Record 5 of Set 4 | griffith
# Processing Record 6 of Set 4 | husavik
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | kavaratti
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | shirgaon
# Processing Record 11 of Set 4 | vila franca do campo
# Processing Record 12 of Set 4 | santa rosa
# Processing Record 13 of Set 4 | cape town
# Processing Record 14 of Set 4 | praia da vitoria
# Processing Record 15 of Set 4 | hay river
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | kemijarvi
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | aktash
# Processing Record 23 of Set 4 | mulege
# Processing Record 24 of Set 4 | san martin
# Processing Record 25 of Set 4 | cravo norte
# Processing Record 26 of Set 4 | laguna
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | pingzhuang
# Processing Record 29 of Set 4 | paamiut
# Processing Record 30 of Set 4 | clarence town
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | tual
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | inta
# Processing Record 35 of Set 4 | ipixuna
# Processing Record 36 of Set 4 | sao joao da barra
# Processing Record 37 of Set 4 | lima
# Processing Record 38 of Set 4 | gordeyevka
# Processing Record 39 of Set 4 | xining
# Processing Record 40 of Set 4 | havoysund
# Processing Record 41 of Set 4 | gat
# Processing Record 42 of Set 4 | slave lake
# Processing Record 43 of Set 4 | kasongo-lunda
# Processing Record 44 of Set 4 | kattivakkam
# Processing Record 45 of Set 4 | lexington park
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | maniitsoq
# Processing Record 48 of Set 4 | mount gambier
# Processing Record 49 of Set 4 | capinopolis
# Processing Record 50 of Set 4 | maragogi
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | mount pleasant
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | doka
# Processing Record 5 of Set 5 | katobu
# Processing Record 6 of Set 5 | mashhad
# Processing Record 7 of Set 5 | esmeraldas
# Processing Record 8 of Set 5 | grindavik
# Processing Record 9 of Set 5 | liberia
# Processing Record 10 of Set 5 | cheyenne
# Processing Record 11 of Set 5 | kahului
# Processing Record 12 of Set 5 | yerbogachen
# Processing Record 13 of Set 5 | nikolskoye
# Processing Record 14 of Set 5 | tautira
# Processing Record 15 of Set 5 | opuwo
# Processing Record 16 of Set 5 | lexington
# Processing Record 17 of Set 5 | sindand
# City not found. Skipping...
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | missoula
# Processing Record 20 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 5 | zhigansk
# Processing Record 22 of Set 5 | tatarsk
# Processing Record 23 of Set 5 | pangnirtung
# Processing Record 24 of Set 5 | santiago de chuco
# Processing Record 25 of Set 5 | kuhdasht
# Processing Record 26 of Set 5 | ternate
# Processing Record 27 of Set 5 | cap malheureux
# Processing Record 28 of Set 5 | traverse city
# Processing Record 29 of Set 5 | chase
# Processing Record 30 of Set 5 | lata
# Processing Record 31 of Set 5 | portland
# Processing Record 32 of Set 5 | canon city
# Processing Record 33 of Set 5 | muisne
# Processing Record 34 of Set 5 | muros
# Processing Record 35 of Set 5 | lagoa
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | cidreira
# Processing Record 38 of Set 5 | mombetsu
# Processing Record 39 of Set 5 | aksu
# Processing Record 40 of Set 5 | mackay
# Processing Record 41 of Set 5 | borba
# Processing Record 42 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 5 | krasnoselkup
# Processing Record 44 of Set 5 | constitucion
# Processing Record 45 of Set 5 | rio grande
# Processing Record 46 of Set 5 | port macquarie
# Processing Record 47 of Set 5 | liverpool
# Processing Record 48 of Set 5 | honningsvag
# Processing Record 49 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 5 | udachnyy
# Processing Record 1 of Set 6 | coahuayana
# Processing Record 2 of Set 6 | nuzvid
# Processing Record 3 of Set 6 | beloha
# Processing Record 4 of Set 6 | mehamn
# Processing Record 5 of Set 6 | tambul
# City not found. Skipping...
# Processing Record 6 of Set 6 | cabo san lucas
# Processing Record 7 of Set 6 | bay roberts
# Processing Record 8 of Set 6 | canico
# Processing Record 9 of Set 6 | gebre guracha
# Processing Record 10 of Set 6 | lebu
# Processing Record 11 of Set 6 | coihaique
# Processing Record 12 of Set 6 | bandarbeyla
# Processing Record 13 of Set 6 | mugur-aksy
# Processing Record 14 of Set 6 | inhambane
# Processing Record 15 of Set 6 | port lincoln
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | meulaboh
# Processing Record 18 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 6 | shimoda
# Processing Record 20 of Set 6 | sakakah
# Processing Record 21 of Set 6 | manaquiri
# Processing Record 22 of Set 6 | deogarh
# Processing Record 23 of Set 6 | lucapa
# Processing Record 24 of Set 6 | hambantota
# Processing Record 25 of Set 6 | maceio
# Processing Record 26 of Set 6 | galesong
# Processing Record 27 of Set 6 | coalinga
# Processing Record 28 of Set 6 | ilulissat
# Processing Record 29 of Set 6 | sao jose da coroa grande
# Processing Record 30 of Set 6 | trinidad
# Processing Record 31 of Set 6 | parabel
# Processing Record 32 of Set 6 | port hawkesbury
# Processing Record 33 of Set 6 | nouadhibou
# Processing Record 34 of Set 6 | acajutla
# Processing Record 35 of Set 6 | emba
# Processing Record 36 of Set 6 | quatre cocos
# Processing Record 37 of Set 6 | waipawa
# Processing Record 38 of Set 6 | kurchum
# Processing Record 39 of Set 6 | saint-pacome
# City not found. Skipping...
# Processing Record 40 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 6 | san jeronimito
# Processing Record 42 of Set 6 | kourou
# Processing Record 43 of Set 6 | luganville
# Processing Record 44 of Set 6 | kaeo
# Processing Record 45 of Set 6 | kloulklubed
# Processing Record 46 of Set 6 | borogontsy
# Processing Record 47 of Set 6 | alberton
# Processing Record 48 of Set 6 | novyy urengoy
# Processing Record 49 of Set 6 | camocim
# Processing Record 50 of Set 6 | boyolangu
# Processing Record 1 of Set 7 | marrakesh
# Processing Record 2 of Set 7 | berlevag
# Processing Record 3 of Set 7 | bonoua
# Processing Record 4 of Set 7 | biltine
# Processing Record 5 of Set 7 | leshukonskoye
# Processing Record 6 of Set 7 | yuzawa
# Processing Record 7 of Set 7 | margate
# Processing Record 8 of Set 7 | atar
# Processing Record 9 of Set 7 | lorengau
# Processing Record 10 of Set 7 | nauta
# Processing Record 11 of Set 7 | klaksvik
# Processing Record 12 of Set 7 | burnie
# Processing Record 13 of Set 7 | benghazi
# Processing Record 14 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 7 | santa isabel
# Processing Record 16 of Set 7 | vigrestad
# Processing Record 17 of Set 7 | ploemeur
# Processing Record 18 of Set 7 | nome
# Processing Record 19 of Set 7 | rovenki
# Processing Record 20 of Set 7 | asyut
# Processing Record 21 of Set 7 | freeport
# Processing Record 22 of Set 7 | san quintin
# Processing Record 23 of Set 7 | oranjemund
# Processing Record 24 of Set 7 | broome
# Processing Record 25 of Set 7 | biograd na moru
# Processing Record 26 of Set 7 | laukaa
# Processing Record 27 of Set 7 | khani
# Processing Record 28 of Set 7 | poum
# Processing Record 29 of Set 7 | srednekolymsk
# Processing Record 30 of Set 7 | kosonsoy
# Processing Record 31 of Set 7 | tukrah
# Processing Record 32 of Set 7 | bridlington
# Processing Record 33 of Set 7 | vestmanna
# Processing Record 34 of Set 7 | vostok
# Processing Record 35 of Set 7 | los llanos de aridane
# Processing Record 36 of Set 7 | nelson bay
# Processing Record 37 of Set 7 | roma
# Processing Record 38 of Set 7 | meadow lake
# Processing Record 39 of Set 7 | beringovskiy
# Processing Record 40 of Set 7 | maldonado
# Processing Record 41 of Set 7 | shache
# Processing Record 42 of Set 7 | severo-kurilsk
# Processing Record 43 of Set 7 | pevek
# Processing Record 44 of Set 7 | vila do maio
# Processing Record 45 of Set 7 | uren
# Processing Record 46 of Set 7 | raudeberg
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | jinhua
# Processing Record 49 of Set 7 | hualmay
# Processing Record 50 of Set 7 | iquitos
# Processing Record 1 of Set 8 | addis zemen
# City not found. Skipping...
# Processing Record 2 of Set 8 | sitka
# Processing Record 3 of Set 8 | palmas bellas
# Processing Record 4 of Set 8 | diapaga
# Processing Record 5 of Set 8 | champerico
# Processing Record 6 of Set 8 | siguiri
# Processing Record 7 of Set 8 | mehriz
# Processing Record 8 of Set 8 | sorland
# Processing Record 9 of Set 8 | savalou
# Processing Record 10 of Set 8 | kodinsk
# Processing Record 11 of Set 8 | pemangkat
# Processing Record 12 of Set 8 | perico
# Processing Record 13 of Set 8 | ostersund
# Processing Record 14 of Set 8 | lazaro cardenas
# Processing Record 15 of Set 8 | klyuchi
# Processing Record 16 of Set 8 | banjar
# Processing Record 17 of Set 8 | kerrobert
# Processing Record 18 of Set 8 | lander
# Processing Record 19 of Set 8 | mariental
# Processing Record 20 of Set 8 | nouakchott
# Processing Record 21 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 8 | walvis bay
# Processing Record 23 of Set 8 | iwanai
# Processing Record 24 of Set 8 | aconibe
# Processing Record 25 of Set 8 | kem
# Processing Record 26 of Set 8 | hovd
# Processing Record 27 of Set 8 | fier
# Processing Record 28 of Set 8 | negara
# Processing Record 29 of Set 8 | tongchuan
# Processing Record 30 of Set 8 | florida
# Processing Record 31 of Set 8 | ust-karsk
# Processing Record 32 of Set 8 | half moon bay
# Processing Record 33 of Set 8 | lavrentiya
# Processing Record 34 of Set 8 | tazovskiy
# Processing Record 35 of Set 8 | bagdarin
# Processing Record 36 of Set 8 | rocha
# Processing Record 37 of Set 8 | kenai
# Processing Record 38 of Set 8 | urucara
# Processing Record 39 of Set 8 | talnakh
# Processing Record 40 of Set 8 | nantucket
# Processing Record 41 of Set 8 | buraydah
# Processing Record 42 of Set 8 | itoman
# Processing Record 43 of Set 8 | comodoro rivadavia
# Processing Record 44 of Set 8 | kijang
# Processing Record 45 of Set 8 | provideniya
# Processing Record 46 of Set 8 | calvinia
# Processing Record 47 of Set 8 | elk plain
# Processing Record 48 of Set 8 | willowmore
# Processing Record 49 of Set 8 | thompson
# Processing Record 50 of Set 8 | marsh harbour
# Processing Record 1 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 2 of Set 9 | lincoln
# Processing Record 3 of Set 9 | varhaug
# Processing Record 4 of Set 9 | xocali
# Processing Record 5 of Set 9 | berbera
# Processing Record 6 of Set 9 | uthal
# Processing Record 7 of Set 9 | namatanai
# Processing Record 8 of Set 9 | sinnamary
# Processing Record 9 of Set 9 | avera
# Processing Record 10 of Set 9 | berdigestyakh
# Processing Record 11 of Set 9 | clyde river
# Processing Record 12 of Set 9 | ossora
# Processing Record 13 of Set 9 | yurga
# Processing Record 14 of Set 9 | mopti
# Processing Record 15 of Set 9 | guangyuan
# Processing Record 16 of Set 9 | alindao
# Processing Record 17 of Set 9 | uniara
# Processing Record 18 of Set 9 | spas-klepiki
# Processing Record 19 of Set 9 | sept-iles
# Processing Record 20 of Set 9 | langsa
# Processing Record 21 of Set 9 | gushikawa
# Processing Record 22 of Set 9 | espita
# Processing Record 23 of Set 9 | abha
# Processing Record 24 of Set 9 | alikovo
# Processing Record 25 of Set 9 | burla
# Processing Record 26 of Set 9 | deer lake
# Processing Record 27 of Set 9 | la ronge
# Processing Record 28 of Set 9 | manta
# Processing Record 29 of Set 9 | diu
# Processing Record 30 of Set 9 | usinsk
# Processing Record 31 of Set 9 | henties bay
# Processing Record 32 of Set 9 | fez
# Processing Record 33 of Set 9 | kiunga
# Processing Record 34 of Set 9 | talcahuano
# Processing Record 35 of Set 9 | sao filipe
# Processing Record 36 of Set 9 | balkanabat
# Processing Record 37 of Set 9 | shenzhen
# Processing Record 38 of Set 9 | tari
# Processing Record 39 of Set 9 | vikhorevka
# Processing Record 40 of Set 9 | nicoya
# Processing Record 41 of Set 9 | shubarshi
# Processing Record 42 of Set 9 | hazaribag
# Processing Record 43 of Set 9 | jiazi
# Processing Record 44 of Set 9 | honggang
# Processing Record 45 of Set 9 | barcelos
# Processing Record 46 of Set 9 | sioux lookout
# Processing Record 47 of Set 9 | mahabad
# Processing Record 48 of Set 9 | necochea
# Processing Record 49 of Set 9 | kailua
# Processing Record 50 of Set 9 | warri
# Processing Record 1 of Set 10 | marawi
# Processing Record 2 of Set 10 | southend-on-sea
# Processing Record 3 of Set 10 | jiamusi
# Processing Record 4 of Set 10 | topolobampo
# Processing Record 5 of Set 10 | sahy
# Processing Record 6 of Set 10 | yola
# Processing Record 7 of Set 10 | yar-sale
# Processing Record 8 of Set 10 | katherine
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | kamenka
# Processing Record 11 of Set 10 | lambarene
# Processing Record 12 of Set 10 | ust-kuyga
# Processing Record 13 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 10 | guerrero negro
# Processing Record 15 of Set 10 | presidente epitacio
# Processing Record 16 of Set 10 | oksfjord
# Processing Record 17 of Set 10 | barroualie
# City not found. Skipping...
# Processing Record 18 of Set 10 | adre
# Processing Record 19 of Set 10 | ludvika
# Processing Record 20 of Set 10 | mahebourg
# Processing Record 21 of Set 10 | vao
# Processing Record 22 of Set 10 | rhyl
# Processing Record 23 of Set 10 | tenenkou
# Processing Record 24 of Set 10 | kaseda
# Processing Record 25 of Set 10 | agogo
# Processing Record 26 of Set 10 | artyom
# Processing Record 27 of Set 10 | beidao
# Processing Record 28 of Set 10 | oltu
# Processing Record 29 of Set 10 | heihe
# Processing Record 30 of Set 10 | sulphur
# Processing Record 31 of Set 10 | kastamonu
# Processing Record 32 of Set 10 | juneau
# Processing Record 33 of Set 10 | lakatoro
# Processing Record 34 of Set 10 | clifton
# Processing Record 35 of Set 10 | great bend
# Processing Record 36 of Set 10 | kangavar
# Processing Record 37 of Set 10 | port-cartier
# Processing Record 38 of Set 10 | coquimbo
# Processing Record 39 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 10 | acari
# Processing Record 41 of Set 10 | auki
# Processing Record 42 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 43 of Set 10 | fairbanks
# Processing Record 44 of Set 10 | montijo
# Processing Record 45 of Set 10 | dawson
# Processing Record 46 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 10 | itarema
# Processing Record 48 of Set 10 | saint-joseph
# Processing Record 49 of Set 10 | daro
# Processing Record 50 of Set 10 | corralillo
# Processing Record 1 of Set 11 | dimona
# Processing Record 2 of Set 11 | grand gaube
# Processing Record 3 of Set 11 | ostrovnoy
# Processing Record 4 of Set 11 | bergerac
# Processing Record 5 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 6 of Set 11 | svenstrup
# Processing Record 7 of Set 11 | bendigo
# Processing Record 8 of Set 11 | batouri
# Processing Record 9 of Set 11 | mandalgovi
# Processing Record 10 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | balikpapan
# Processing Record 12 of Set 11 | inirida
# Processing Record 13 of Set 11 | montrose
# Processing Record 14 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 15 of Set 11 | blackwater
# Processing Record 16 of Set 11 | haines junction
# Processing Record 17 of Set 11 | san carlos de bariloche
# Processing Record 18 of Set 11 | ardmore
# Processing Record 19 of Set 11 | namibe
# Processing Record 20 of Set 11 | arlit
# Processing Record 21 of Set 11 | dandong
# Processing Record 22 of Set 11 | padang
# Processing Record 23 of Set 11 | baghdad
# Processing Record 24 of Set 11 | les cayes
# Processing Record 25 of Set 11 | kysyl-syr
# Processing Record 26 of Set 11 | karasburg
# Processing Record 27 of Set 11 | high level
# Processing Record 28 of Set 11 | ardabil
# Processing Record 29 of Set 11 | jian
# Processing Record 30 of Set 11 | callaway
# Processing Record 31 of Set 11 | rawson
# Processing Record 32 of Set 11 | ancud
# Processing Record 33 of Set 11 | plouzane
# Processing Record 34 of Set 11 | pangoa
# Processing Record 35 of Set 11 | bella union
# Processing Record 36 of Set 11 | jiaojiang
# Processing Record 37 of Set 11 | panindicuaro
# Processing Record 38 of Set 11 | katsuura
# Processing Record 39 of Set 11 | kirillov
# Processing Record 40 of Set 11 | atherton
# Processing Record 41 of Set 11 | coruripe
# Processing Record 42 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 11 | chaman
# Processing Record 44 of Set 11 | dengzhou
# Processing Record 45 of Set 11 | worland
# Processing Record 46 of Set 11 | itanhem
# Processing Record 47 of Set 11 | jardim
# Processing Record 48 of Set 11 | banting
# Processing Record 49 of Set 11 | umm kaddadah
# Processing Record 50 of Set 11 | whitehorse
# Processing Record 1 of Set 12 | bathsheba
# Processing Record 2 of Set 12 | raxaul
# Processing Record 3 of Set 12 | coaticook
# Processing Record 4 of Set 12 | mae sot
# Processing Record 5 of Set 12 | assiniboia
# Processing Record 6 of Set 12 | alofi
# Processing Record 7 of Set 12 | ilam
# Processing Record 8 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 9 of Set 12 | saint-augustin
# Processing Record 10 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 12 | tarifa
# Processing Record 12 of Set 12 | bereda
# Processing Record 13 of Set 12 | milkovo
# Processing Record 14 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 12 | teahupoo
# Processing Record 16 of Set 12 | ueki
# Processing Record 17 of Set 12 | linkou
# Processing Record 18 of Set 12 | sibolga
# Processing Record 19 of Set 12 | poli
# Processing Record 20 of Set 12 | aligudarz
# Processing Record 21 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 12 | kununurra
# Processing Record 23 of Set 12 | port-gentil
# Processing Record 24 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 12 | igarka
# Processing Record 26 of Set 12 | nimaparha
# Processing Record 27 of Set 12 | banyo
# Processing Record 28 of Set 12 | puerto escondido
# Processing Record 29 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 30 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 12 | cody
# Processing Record 32 of Set 12 | benguela
# Processing Record 33 of Set 12 | nong kung si
# Processing Record 34 of Set 12 | seoul
# Processing Record 35 of Set 12 | moroni
# Processing Record 36 of Set 12 | kruisfontein
# Processing Record 37 of Set 12 | challans
# Processing Record 38 of Set 12 | ous
# Processing Record 39 of Set 12 | herveo
# Processing Record 40 of Set 12 | saint-georges
# Processing Record 41 of Set 12 | quelimane
# Processing Record 42 of Set 12 | urumqi
# Processing Record 43 of Set 12 | nizhnyaya tavda
# Processing Record 44 of Set 12 | nizhniy kuranakh
# Processing Record 45 of Set 12 | tabou
# Processing Record 46 of Set 12 | vestmannaeyjar
# Processing Record 47 of Set 12 | jishou
# Processing Record 48 of Set 12 | atasu
# Processing Record 49 of Set 12 | tateyama
# Processing Record 50 of Set 12 | pachelma
# Processing Record 1 of Set 13 | kudat
# Processing Record 2 of Set 13 | taltal
# Processing Record 3 of Set 13 | ankang
# Processing Record 4 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 13 | kishi
# Processing Record 6 of Set 13 | horki
# Processing Record 7 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 13 | burns lake
# Processing Record 9 of Set 13 | grigiskes
# Processing Record 10 of Set 13 | nacogdoches
# Processing Record 11 of Set 13 | tenkodogo
# Processing Record 12 of Set 13 | doha
# Processing Record 13 of Set 13 | abdulino
# Processing Record 14 of Set 13 | upata
# Processing Record 15 of Set 13 | karonga
# Processing Record 16 of Set 13 | darhan
# Processing Record 17 of Set 13 | rovaniemi
# Processing Record 18 of Set 13 | jalu
# Processing Record 19 of Set 13 | kudahuvadhoo
# Processing Record 20 of Set 13 | petatlan
# Processing Record 21 of Set 13 | lutin
# Processing Record 22 of Set 13 | charters towers
# Processing Record 23 of Set 13 | turukhansk
# Processing Record 24 of Set 13 | barinas
# Processing Record 25 of Set 13 | almeirim
# Processing Record 26 of Set 13 | thinadhoo
# Processing Record 27 of Set 13 | salta
# Processing Record 28 of Set 13 | rio gallegos
# Processing Record 29 of Set 13 | general roca
# Processing Record 30 of Set 13 | sol-iletsk
# Processing Record 31 of Set 13 | yongan
# Processing Record 32 of Set 13 | namtsy
# Processing Record 33 of Set 13 | pangai
# Processing Record 34 of Set 13 | paramonga
# Processing Record 35 of Set 13 | fasa
# Processing Record 36 of Set 13 | sibu
# Processing Record 37 of Set 13 | karratha
# Processing Record 38 of Set 13 | iskateley
# Processing Record 39 of Set 13 | batesville
# Processing Record 40 of Set 13 | la libertad
# Processing Record 41 of Set 13 | kampot
# Processing Record 42 of Set 13 | tlaxco
# Processing Record 43 of Set 13 | antofagasta
# Processing Record 44 of Set 13 | eureka
# Processing Record 45 of Set 13 | sola
# Processing Record 46 of Set 13 | leningradskiy
# Processing Record 47 of Set 13 | alyangula
# Processing Record 48 of Set 13 | concordia
# Processing Record 49 of Set 13 | olinda
# Processing Record 50 of Set 13 | lipin bor
# Processing Record 1 of Set 14 | mareeba
# Processing Record 2 of Set 14 | murray bridge
# Processing Record 3 of Set 14 | mount isa
# Processing Record 4 of Set 14 | inuvik
# Processing Record 5 of Set 14 | togur
# Processing Record 6 of Set 14 | mokhsogollokh
# Processing Record 7 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 14 | bitung
# Processing Record 9 of Set 14 | amalner
# Processing Record 10 of Set 14 | elizabeth city
# Processing Record 11 of Set 14 | fukuma
# Processing Record 12 of Set 14 | darab
# Processing Record 13 of Set 14 | yeppoon
# Processing Record 14 of Set 14 | verkhnevilyuysk
# Processing Record 15 of Set 14 | ratnagiri
# Processing Record 16 of Set 14 | palauig
# Processing Record 17 of Set 14 | marzuq
# Processing Record 18 of Set 14 | makrana
# Processing Record 19 of Set 14 | ketchikan
# Processing Record 20 of Set 14 | mineral wells
# Processing Record 21 of Set 14 | ambon
# Processing Record 22 of Set 14 | richards bay
# Processing Record 23 of Set 14 | mogoytuy
# Processing Record 24 of Set 14 | oranzherei
# Processing Record 25 of Set 14 | sinjai
# Processing Record 26 of Set 14 | shirokiy
# Processing Record 27 of Set 14 | hami
# Processing Record 28 of Set 14 | valdivia
# Processing Record 29 of Set 14 | kamaishi
# Processing Record 30 of Set 14 | mosetse
# Processing Record 31 of Set 14 | tommot
# Processing Record 32 of Set 14 | mazatlan
# Processing Record 33 of Set 14 | mayya
# Processing Record 34 of Set 14 | vardo
# Processing Record 35 of Set 14 | nabire
# Processing Record 36 of Set 14 | jambi
# Processing Record 37 of Set 14 | sasina
# Processing Record 38 of Set 14 | isangel
# Processing Record 39 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 14 | bud
# Processing Record 41 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 14 | muroto
# Processing Record 43 of Set 14 | aswan
# Processing Record 44 of Set 14 | beruwala
# Processing Record 45 of Set 14 | svetlogorsk
# Processing Record 46 of Set 14 | dagua
# Processing Record 47 of Set 14 | rancho palos verdes
# Processing Record 48 of Set 14 | isla vista
# Processing Record 49 of Set 14 | kargasok
# Processing Record 50 of Set 14 | ulaangom
# Processing Record 1 of Set 15 | aguilas
# Processing Record 2 of Set 15 | asau
# Processing Record 3 of Set 15 | monterey
# Processing Record 4 of Set 15 | makkaveyevo
# Processing Record 5 of Set 15 | kharp
# Processing Record 6 of Set 15 | kangaatsiaq
# Processing Record 7 of Set 15 | mehran
# Processing Record 8 of Set 15 | xichang
# Processing Record 9 of Set 15 | tromso
# Processing Record 10 of Set 15 | bourges
# Processing Record 11 of Set 15 | wakkanai
# Processing Record 12 of Set 15 | sumbe
# Processing Record 13 of Set 15 | pemberton
# Processing Record 14 of Set 15 | krasnyy yar
# Processing Record 15 of Set 15 | college
# Processing Record 16 of Set 15 | korla
# Processing Record 17 of Set 15 | praia
# Processing Record 18 of Set 15 | rantepao
# Processing Record 19 of Set 15 | baruun-urt
# Processing Record 20 of Set 15 | ewa beach
# Processing Record 21 of Set 15 | the pas
# Processing Record 22 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 15 | bosaso
# Processing Record 24 of Set 15 | salalah
# Processing Record 25 of Set 15 | aripuana
# Processing Record 26 of Set 15 | koulikoro
# Processing Record 27 of Set 15 | phek
# Processing Record 28 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 15 | bilsi
# Processing Record 30 of Set 15 | marienburg
# Processing Record 31 of Set 15 | plettenberg bay
# Processing Record 32 of Set 15 | el sauzal
# Processing Record 33 of Set 15 | yulara
# Processing Record 34 of Set 15 | ust-ilimsk
# Processing Record 35 of Set 15 | gladzor
# Processing Record 36 of Set 15 | iquique
# Processing Record 37 of Set 15 | sangar
# Processing Record 38 of Set 15 | mangrol
# Processing Record 39 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 15 | hofn
# Processing Record 41 of Set 15 | sobolevo
# Processing Record 42 of Set 15 | palmer
# Processing Record 43 of Set 15 | zahir pir
# Processing Record 44 of Set 15 | khash
# Processing Record 45 of Set 15 | dubrovnik
# Processing Record 46 of Set 15 | bac lieu
# Processing Record 47 of Set 15 | pitimbu
# Processing Record 48 of Set 15 | nacala
# Processing Record 49 of Set 15 | ottawa
# Processing Record 50 of Set 15 | tawau
# Processing Record 1 of Set 16 | abeche
# Processing Record 2 of Set 16 | yablonovo
# Processing Record 3 of Set 16 | banda aceh
# Processing Record 4 of Set 16 | mauganj
# Processing Record 5 of Set 16 | kashi
# Processing Record 6 of Set 16 | ziyamet
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng        Conditions  Max Temp  Humidity  \
# 0        Ushuaia -54.8000  -68.3000     broken clouds     38.86        87
# 1       Tasiilaq  65.6145  -37.6368   overcast clouds     32.16        95
# 2        Qaanaaq  77.4840  -69.3632     broken clouds     13.21        75
# 3          Bluff -46.6000  168.3333     broken clouds     52.81        78
# 4  Pacific Grove  36.6177 -121.9166         clear sky     72.01        70
# 5         Bethel  41.3712  -73.4140   overcast clouds     57.07        91
# 6         Hobart -42.8794  147.3294     broken clouds     50.27        94
# 7         Castro -24.7911  -50.0119  scattered clouds     64.18        92
# 8         Albany  42.6001  -73.9662   overcast clouds     53.38        90
# 9          Kapaa  22.0752 -159.3190        light rain     80.58        84
#
#    Cloudiness  Wind Speed Country                 Date
# 0          75       12.66      AR  2022-04-26 22:33:37
# 1          91        4.03      GL  2022-04-26 22:35:52
# 2          67        5.88      GL  2022-04-26 22:35:53
# 3          83        8.93      NZ  2022-04-26 22:35:54
# 4           0       17.00      US  2022-04-26 22:35:54
# 5         100        4.61      US  2022-04-26 22:35:54
# 6          75        6.91      AU  2022-04-26 22:31:48
# 7          30        4.92      BR  2022-04-26 22:35:55
# 8         100        4.56      US  2022-04-26 22:33:33
# 9         100       12.66      US  2022-04-26 22:34:24

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Conditions","Max Temp","Humidity","Cloudiness","Wind Speed"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#             City Country                 Date      Lat       Lng  \
# 0        Ushuaia      AR  2022-04-26 22:33:37 -54.8000  -68.3000
# 1       Tasiilaq      GL  2022-04-26 22:35:52  65.6145  -37.6368
# 2        Qaanaaq      GL  2022-04-26 22:35:53  77.4840  -69.3632
# 3          Bluff      NZ  2022-04-26 22:35:54 -46.6000  168.3333
# 4  Pacific Grove      US  2022-04-26 22:35:54  36.6177 -121.9166
#
#         Conditions  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    broken clouds     38.86        87          75       12.66
# 1  overcast clouds     32.16        95          91        4.03
# 2    broken clouds     13.21        75          67        5.88
# 3    broken clouds     52.81        78          83        8.93
# 4        clear sky     72.01        70           0       17.00

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
